# %%
from bs4 import BeautifulSoup
import requests
import json
import pprint

url = "https://www.youtube.com/playlist?list=PLBh2i93oe2qvyrgm_lchujtMbEdXFAHEQ" #input("Input playlist URL: ")

r = requests.get(url)

# print(r.content)

soup = BeautifulSoup(r.content,"html.parser")

# %%
soup.find_all('div', attrs = {'id':'content'})
# Out:
# []

# %%
for script in soup.find_all('script'):
    if "var ytInitialData" in str(script):
        parts = script.text.split(" ")[3:]

line = ""

for part in parts:
    line += part + " "

line = line[0:-2]
# print(line)

# with open("line.txt",'w') as file:
#     file.write(line)
info = json.loads(line)

video_list = info['contents']['twoColumnBrowseResultsRenderer']['tabs'][0]['tabRenderer']['content']['sectionListRenderer']['contents'][0]['itemSectionRenderer']['contents'][0]['playlistVideoListRenderer']['contents']
ids =[]
youtubers = []
titles = []
for video in video_list:
    try:
        titles.append(video['playlistVideoRenderer']['title']['runs'][0]['text'])
    except KeyError:
        continue
    youtubers.append(video['playlistVideoRenderer']['shortBylineText']['runs'][0]['text'])
    ids.append(video['playlistVideoRenderer']['navigationEndpoint']['commandMetadata']['webCommandMetadata']['url'])
    
for i,id in enumerate(ids):
    print(f"[{youtubers[i]} | {titles[i]}](https://www.youtube.com{id})")
# Out:
# [The Bright Side of Mathematics | Abstract Linear Algebra 1 | Vector Space](https://www.youtube.com/watch?v=HCX1j_aTQGs&list=PLBh2i93oe2qvyrgm_lchujtMbEdXFAHEQ&index=1&pp=iAQB)
# [The Bright Side of Mathematics | Abstract Linear Algebra 2 | Examples of Abstract Vector Spaces](https://www.youtube.com/watch?v=ZA4rGQ2oGnM&list=PLBh2i93oe2qvyrgm_lchujtMbEdXFAHEQ&index=2&pp=iAQB)
# [The Bright Side of Mathematics | Abstract Linear Algebra 3 | Linear Subspaces](https://www.youtube.com/watch?v=Ek5Ebm6t6nY&list=PLBh2i93oe2qvyrgm_lchujtMbEdXFAHEQ&index=3&pp=iAQB)
# [The Bright Side of Mathematics | Abstract Linear Algebra 4 | Basis, Linear Independence, Generating Sets](https://www.youtube.com/watch?v=D69BiRT2UDI&list=PLBh2i93oe2qvyrgm_lchujtMbEdXFAHEQ&index=4&pp=iAQB)
# [The Bright Side of Mathematics | Abstract Linear Algebra 5 | Coordinates and Basis Isomorphism](https://www.youtube.com/watch?v=v7I8ba6aAAQ&list=PLBh2i93oe2qvyrgm_lchujtMbEdXFAHEQ&index=5&pp=iAQB)
# ...

# %%
soup.find("body")
# Out:
# <body dir="ltr"><script nonce="_dQMUVfxyebDXsEX3onjmg">if (window.ytcsi) {window.ytcsi.tick('bs', null, '');}</script><script nonce="_dQMUVfxyebDXsEX3onjmg">ytcfg.set('initialBodyClientWidth', document.body.clientWidth);</script><script nonce="_dQMUVfxyebDXsEX3onjmg">if (window.ytcsi) {window.ytcsi.tick('ai', null, '');}</script><iframe name="passive_signin" src="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den-GB%26next%3D%252Fsignin_passive%26feature%3Dpassive&amp;hl=en-GB" style="display: none"></iframe><ytd-app><ytd-masthead class="shell" id="masthead" logo-type="YOUTUBE_LOGO" slot="masthead"><div class="ytd-searchbox-spt" id="search-container" slot="search-container"></div><div class="ytd-searchbox-spt" id="search-input" slot="search-input"><input autocapitalize="none" autocomplete="off" autocorrect="off" hidden="" id="search" name="sea
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html darker-dark-theme="" darker-dark-theme-deprecate="" lang="en-GB" style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" system-icons="" typography="" typography-spacing="">
#  <head>
#   <script data-id="_gd" nonce="_dQMUVfxyebDXsEX3onjmg">
#    window.WIZ_global_data = {"MUE6Ne":"youtube_web","MuJWjd":false,"cfb2h":"youtube.web-front-end-critical_20240912.08_p1","fPDxwd":[],"iCzhFc":false,"nQyAE":{},"oxN3nb":{"1":false,"0":false,"610401301":false,"899588437":false,"188588736":true,"644029907":true,"1822726157":true,"661449076":false,"651175828":false,"653718497":false,"660014094":false},"yFnxrf":2486};
#   </script>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# ...
